# %%
import os
 
path = 'C:/Users/Aditya/Documents/Datathon/articles/'
 
files = os.listdir(path)

articles_list = []

for name in files: 
        articles_list.append(name)

# %%
articles_list
# Out:
# ['article111111112.txt',
#  'article111111113.txt',
#  'article111111122.txt',
#  'article111111124.txt',
#  'article111111131.txt',
#  'article111111132.txt',
#  'article111111134.txt',
#  'article111111137.txt',
#  'article694327499.txt',
#  'article694811415.txt',
#  'article695108099.txt',
#  'article695833178.txt',
#  'article696246189.txt',
#  'article696264594.txt',
#  'article696694316.txt',
#  'article696735702.txt',
#  'article697063039.txt',
#  'article697444415.txt',
#  'article697454736.txt',
#  'article697472447.txt',
#  'article697959084.txt',
#  'article697996062.txt',
#  'article698018235.txt',
#  'article698092698.txt',
#  'article698780559.txt',
#  'article700551604.txt',
#  'article700662577.txt',
#  'article701225819.txt',
#  'article701553469.txt',
#  'article701837665.txt',
#  'article701939679.txt',
#  'article702077434.txt',
#  'article702077783.txt',
#  'article703698295.txt',
#  'article703806098.txt',
#  'article703821117.txt',
#  'article704591553.txt',
# ...

# %%
path = 'C:/Users/Aditya/Documents/Datathon/train/'
 
files = os.listdir(path)

task2_list = []

for name in files:
    if 'task2' in name:
        task2_list.append(name)

# %%
path = 'C:/Users/Aditya/Documents/Datathon/train/'
 
files = os.listdir(path)

task3_list = []

for name in files:
    if 'task3' in name:
        task3_list.append(name)

# %%
import shutil

# %%
paths = []
for name in task2_list:
        name = 'C:/Users/Aditya/Documents/Datathon/train/' + name
        paths.append(name)

# %%
#os.mkdir('task2')
for f in paths:
    shutil.copy(f, 'task-2')

# %%
paths = []
for name in task3_list:
        name = 'C:/Users/Aditya/Documents/Datathon/train/' + name
        paths.append(name)

# %%
#os.mkdir('task3')
for f in paths:
    shutil.copy(f, 'task-3')

# %%
paths = []
for name in articles_list:
        name = 'C:/Users/Aditya/Documents/Datathon/train/' + name
        paths.append(name)

# %%
paths[0:5]
# Out:
# ['C:/Users/Aditya/Documents/Datathon/train/article111111112.txt',
#  'C:/Users/Aditya/Documents/Datathon/train/article111111113.txt',
#  'C:/Users/Aditya/Documents/Datathon/train/article111111122.txt',
#  'C:/Users/Aditya/Documents/Datathon/train/article111111124.txt',
#  'C:/Users/Aditya/Documents/Datathon/train/article111111131.txt']

# %%
column3 =[]
for fname in paths:
    with open(fname,'r',encoding='utf-8') as f:
        content = f.readlines()
    # you may also want to remove whitespace characters like `\n` at the end of each line
    content = [x.strip() for x in content]
    column3.extend(content)
#print(content)
#len(content)

# %%
import pandas as pd

# %%
df = pd.DataFrame({'col':column3})

# %%
df.to_csv('column3.csv')

# %%
len(articles_list)
# Out:
# 293
